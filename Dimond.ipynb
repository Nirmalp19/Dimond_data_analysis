# %% [markdown]
# Dimond Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\hp_5C\OneDrive\Desktop\FTN\python\diamonds.csv')

print(df.head())
print()
print(df.tail())
print()
print(df.shape)
print()
print(df.columns)
print()
print(df.info())
print()
print(df.dtypes)
print()
print(df.describe())
print()
# to know how many data is missing from each coloumn of the dataset

print(df.isnull().count())
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75
#
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# ...

# %%
df1=df.drop(columns='Unnamed: 0') #hear after : space is mandetory and 0 is a index no. of first coluumn
print(df1)

print(df1.shape)
print(df1.columns)
print(df1.head())

print(df1['carat'].value_counts())


cutCounts = df1['cut'].value_counts()
print(cutCounts)

colorCounts = df1['color'].value_counts()
print(colorCounts)

claritycounts = df1['clarity'].value_counts()
print(claritycounts)


tableCounts = df1['table'].value_counts()
print(tableCounts)

pricecounts = df1['price'].value_counts()
print(pricecounts)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
# (53940, 10)
# ...

# %%
plt.figure(figsize=[12,6])
plt.hist(df["price"],bins=180,color="pink")
plt.xlabel("Price in USD")
plt.ylabel("Frequency")
plt.title("Dimonds Price Histogram")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df1['price'],df1['carat'])
plt.title('Carat v/s Price')
plt.xlabel('Price')
plt.ylabel('Carat')
plt.show()

# %%
plt.figure(figsize=(12,6))       ## 12,6 size is good for graph put in pdfs bec. it fit exactly
plt.plot(df1['price'],df1['depth'])
plt.title('Depth v/s Price')
plt.xlabel('Price')
plt.ylabel('Depth')
plt.show()

# %%
plt.figure(figsize=(12,6))
cutCounts.plot(kind='line',color="orange")
plt.title('Disttribution of Dimond Cuts')
plt.xlabel('Cut Type')
plt.ylabel('Frequency')
plt.xticks(rotation=20)
plt.yticks(rotation=20)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,6))
cutCounts.plot(kind='bar',color="orange")
plt.title('Disttribution of Dimond Cuts')
plt.xlabel('Cut Type')
plt.ylabel('Frequency')
plt.xticks(rotation=25)
plt.yticks(rotation=25)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,6))
colorCounts.plot(kind='line',color="yellow")
plt.title('Disttribution of Dimond Cuts')
plt.xlabel('Color Type')
plt.ylabel('Frequency')

plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,6))
claritycounts.plot(kind='line',color="yellow")
plt.title('Disttribution of Dimond Cuts')
plt.xlabel('clarity Type')
plt.ylabel('Frequency')

plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,6))
cutCounts.plot(kind='bar',color="skyblue")
plt.title('Disttribution of Dimond Cuts')
plt.xlabel('Cut Type')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(axis='y',linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,6))
cutCounts.plot(kind='pie',autopct='%1.3f%%',colors=['skyblue','lightgreen','orange','lightcoral','gold'])   # hear .3 for 3 decimals after point
plt.title('Distribution of Dimond Cuts')
plt.ylabel('')
plt.show()

# %%
plt.scatter(df1['x'],df1['y'])
plt.title("X-axis v/s Y-axis")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
df.loc[(df['x'] == 0) | (df['y'] == 0) | (df['z'] == 0 )]



drop_index = df.loc[(df['x'] == 0) | (df['y'] == 0) | (df['z'] == 0 )].index

df = df.drop(drop_index)
print(df)
df.describe()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
print(df['cut'].unique())
print(df['color'].unique())
print(df['clarity'].unique())

df['color']=df['color'].factorize()[0]
df['clarity']=df['clarity'].factorize()[0]
df['cut']=df['cut'].factorize()[0]
print(df.head())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']
#    Unnamed: 0  carat  cut  color  clarity  depth  table  price     x     y  \
# 0           1   0.23    0      0        0   61.5   55.0    326  3.95  3.98
# 1           2   0.21    1      0        1   59.8   61.0    326  3.89  3.84
# 2           3   0.23    2      0        2   56.9   65.0    327  4.05  4.07
# 3           4   0.29    1      1        3   62.4   58.0    334  4.20  4.23
# 4           5   0.31    2      2        0   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
buy = df.copy()
buy['price_per_carat'] = buy['price'] / buy['carat']
buy = buy.sort_values(by='price_per_carat',ascending=True)
print(f"Best values for money: {round(min(buy['price_per_carat']),2)}$")
print("The first3:\n")
print(buy.head(3))
# Out:
# Best values for money: 1051.16$
# The first3:
#
#        Unnamed: 0  carat  cut  color  clarity  depth  table  price     x  \
# 31962       31963   0.43    1      3        6   62.0   59.0    452  4.78
# 15             16   0.32    1      0        6   60.9   58.0    345  4.38
# 4               5   0.31    2      2        0   63.3   58.0    335  4.34
#
#           y     z  price_per_carat
# 31962  4.83  2.98      1051.162791
# 15     4.42  2.68      1078.125000
# 4      4.35  2.75      1080.645161

# %%
import seaborn as sns 

df['cut'].value_counts()
df['color'].value_counts()
df['clarity'].value_counts()
sns.countplot(x='cut',data=df,color='green')
sns.countplot(x='color',data=df,color='green')
sns.countplot(x='clarity',data=df,color='green')
labels= df['cut'].unique()
plt.pie(df['cut'].value_counts(),labels=labels)
plt.show()
labels= df['color'].unique()
plt.pie(df['color'].value_counts(),labels=labels)
plt.show()
labels= df['clatity'].unique()
plt.pie(df['clarity'].value_counts(),labels=labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp_5C\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clatity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 15
# ...
